# %%
import pandas as pd

# %%
pd.read_json('CompanyInfo.jl', lines=True)
# Out:
#                                              main_url            company_name  \
# 0   https://www.glassdoor.co.uk/Reviews/london-rev...                    Zara
# 1   https://www.glassdoor.co.uk/Reviews/london-rev...                  Hilton
# 2   https://www.glassdoor.co.uk/Reviews/london-rev...  Marriott International
# 3   https://www.glassdoor.co.uk/Reviews/london-rev...                     NHS
# 4   https://www.glassdoor.co.uk/Reviews/london-rev...              McDonald's
# ..                                                ...                     ...
# 91  https://www.glassdoor.co.uk/Reviews/london-rev...        HCL Technologies
# 92  https://www.glassdoor.co.uk/Reviews/london-rev...                    Uber
# 93  https://www.glassdoor.co.uk/Reviews/london-rev...               FDM Group
# 94  https://www.glassdoor.co.uk/Reviews/london-rev...     Waitrose & Partners
# 95  https://www.glassdoor.co.uk/Reviews/london-rev...     Walt Disney Company
#
# ...

# %%
pd.read_json('Reviews.jl', lines=True)
# Out:
#           company                                         review_url  \
# 0            Zara  https://www.glassdoor.co.uk/Reviews/Zara-Revie...
# 1            Zara  https://www.glassdoor.co.uk/Reviews/Zara-Revie...
# 2            Zara  https://www.glassdoor.co.uk/Reviews/Zara-Revie...
# 3            Zara  https://www.glassdoor.co.uk/Reviews/Zara-Revie...
# 4            Zara  https://www.glassdoor.co.uk/Reviews/Zara-Revie...
# ...           ...                                                ...
# 257145  Starbucks  https://www.glassdoor.co.uk/Reviews/Starbucks-...
# 257146  Starbucks  https://www.glassdoor.co.uk/Reviews/Starbucks-...
# 257147  Starbucks  https://www.glassdoor.co.uk/Reviews/Starbucks-...
# 257148  Starbucks  https://www.glassdoor.co.uk/Reviews/Starbucks-...
# 257149  Starbucks  https://www.glassdoor.co.uk/Reviews/Starbucks-...
#
#                       title  overall_rating  \
# 0                     geeat               5
# 1                     great               5
# ...

# %% [markdown]
# # Sandbox

# %%
def get_inner_html(url):
    browser = webdriver.Chrome(
        CHROMEDRIVER_PATH,
    chrome_options=chrome_options)
    browser.get(url)
    # some time to render .js
    time.sleep(1)
    # returns the inner HTML as a string
    innerHTML = browser.execute_script("return document.body.innerHTML")
    return innerHTML

# %%
import time
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

import platform
PLATFORM = platform.system()
if PLATFORM == 'Darwin': 
    CHROMEDRIVER_PATH = './glassdoor_scraper/spiders/chromedriver'
else:
    CHROMEDRIVER_PATH = './tutorial/chromedriver_linux'
    
WINDOW_SIZE = "1920,1080"
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--window-size=%s" % WINDOW_SIZE)

# %%
url = "https://www.glassdoor.co.uk/Reviews/Banana-Republic-Reviews-E23057.htm"

# %%
browser = webdriver.Chrome(
        CHROMEDRIVER_PATH,
    chrome_options=chrome_options)
browser.get(url)
# Out:
# <ipython-input-128-19dd21afa668>:1: DeprecationWarning: use options instead of chrome_options
#   browser = webdriver.Chrome(

# %%
element = browser.find_element_by_css_selector('div.col-sm-11.pl-sm-lg.mx-0 div.v2__EIReviewDetailsV2__continueReading')

# %%
browser.get_screenshot_as_file('test.png')
# Out:
# True

# %%
inner_html = get_inner_html(url)

soup = BeautifulSoup(inner_html)
# Out:
# <ipython-input-114-dbe74b464d7f>:2: DeprecationWarning: use options instead of chrome_options
#   browser = webdriver.Chrome(

# %%
soup
# Out:
# <html><body><div id="FlexTestFF"><div class="testMQ mqHH"></div><div class="testMQ mqTab"></div><div class="testMQ mqDT"></div></div><div id="UserAlertBarSubstitute"></div><header class="gdGrid" id="TopNav"><nav class="d-flex align-items-center flex-row justify-content-between mx-0"><div class="container-logo d-inline-block col order-first"><a aria-label="Glassdoor" data-test="header-glassdoor-logo" href="/index.htm" target="_top"><svg height="24" title="Glassdoor Logo" viewbox="514 1654 121 24" width="121" xmlns="http://www.w3.org/2000/svg"><path d="M635 1659.548a.413.413 0 0 0-.212-.336c-.274-.138-.674-.232-1.488-.232-1.837 0-3.462.912-4.171 2.438v-1.864a.292.292 0 0 0-.292-.293h-2.751a.292.292 0 0 0-.292.293v12.566c0 .161.13.292.292.292h2.882a.292.292 0 0 0 .292-.292v-5.652c0-2.525 1.756-3.78 4.04-3.78.533 0 1.065.118 1.332.206.183.06.368-.09.368-.283v-3.063zm-18.415 9.78c-1.97 0-3.493-1.393-3.493-3.497s1.524-3.498 3.493-3.498c1.969 0 3.492 1.394 3.492 3.498s-1.523 3.498-3.492 3.4
# ...

# %%
v2__EIReviewDetailsV2__continueReading v2__EIReviewDetailsV2__clickable

# %%
ceo_ratings = None
ceo_ratings =soup.find('div', 'numCEORatings')
if ceo_ratings:
    ceo_ratings = ceo_ratings.text

# %%
ceo_ratings
# Out:
# '295 Ratings'

# %%
import requests
url = 'https://www.glassdoor.co.uk/Reviews/Banana-Republic-Reviews-E23057.htm'

# %%
html = '''<div class="gdReview"><div class="d-flex justify-content-between"><div class="d-flex align-items-center"><time class="date subtle small" datetime="Wed Feb 12 2020 01:30:00 GMT-0800 (Pacific Standard Time)">12 February 2020</time></div></div><div class="row mt"><div class="col-sm-1"><span class="sqLogo smSqLogo logoOverlay"><img alt="Banana Republic Logo" class="lazy lazy-loaded" data-original="https://media.glassdoor.com/sql/23057/banana-republic-squarelogo-1580180139279.png" data-original-2x="https://media.glassdoor.com/sqll/23057/banana-republic-squarelogo-1580180139279.png" data-retina-ok="true" src="https://media.glassdoor.com/sql/23057/banana-republic-squarelogo-1580180139279.png" style="opacity:1" title=""></span></div><div class="col-sm-11 pl-sm-lg mx-0"><h2 class="h2 summary strong mt-0 mb-xsm"><a href="/Reviews/Employee-Review-Banana-Republic-RVW31820120.htm" class="reviewLink">"Best place I\'ve worked"</a></h2><div class="mr-xsm d-lg-inline-block"><span class="gdStars gdRatings subRatings__SubRatingsStyles__gdStars"><div class=" v2__EIReviewsRatingsStylesV2__ratingInfoWrapper"><div class="v2__EIReviewsRatingsStylesV2__ratingInfo" rel="nofollow"><div class="v2__EIReviewsRatingsStylesV2__ratingNum v2__EIReviewsRatingsStylesV2__small">5.0</div><span class="gdStars gdRatings common__StarStyles__gdStars"><span class="rating"><span title="5.0"></span></span><style data-emotion-css="1gf6lcl">.css-1gf6lcl{display:inline-block;line-height:1;font-size:14px;background:linear-gradient(90deg,#0caa41 100%,#dee0e3 100%);-webkit-letter-spacing:3px;-moz-letter-spacing:3px;-ms-letter-spacing:3px;letter-spacing:3px;-webkit-background-clip:text;-webkit-text-fill-color:transparent;cursor:pointer;}</style><div font-size="sm" class="css-1gf6lcl"><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span></div></span><span class="SVGInline"><svg class="SVGInline-svg" style="width: 16;height: 16;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewbox="0 0 24 24"><path d="M4.4 9.25l7.386 7.523a1 1 0 001.428 0L20.6 9.25c.5-.509.5-1.324 0-1.833a1.261 1.261 0 00-1.8 0l-6.3 6.416-6.3-6.416a1.261 1.261 0 00-1.8 0c-.5.509-.5 1.324 0 1.833z" fill-rule="evenodd" fill="currentColor"></path></svg></span></div></div><div class="subRatings module subRatings__SubRatingsStyles__subRatings"><div class="dummyHoverArea"></div><i class="beak subRatings__SubRatingsStyles__beak"></i><ul class="undecorated"><li><div class="minor">Work/Life Balance</div><span class="subRatings__SubRatingsStyles__gdBars gdBars gdRatings med" title="5.0"><span class="gdStars gdRatings common__StarStyles__gdStars"><span class="rating"><span title="5.0"></span></span><div font-size="sm" class="css-1gf6lcl"><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span></div></span></span></li><li><div class="minor">Culture &amp; Values</div><span class="subRatings__SubRatingsStyles__gdBars gdBars gdRatings med" title="5.0"><span class="gdStars gdRatings common__StarStyles__gdStars"><span class="rating"><span title="5.0"></span></span><div font-size="sm" class="css-1gf6lcl"><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span></div></span></span></li><li><div class="minor">Career Opportunities</div><span class="subRatings__SubRatingsStyles__gdBars gdBars gdRatings med" title="5.0"><span class="gdStars gdRatings common__StarStyles__gdStars"><span class="rating"><span title="5.0"></span></span><div font-size="sm" class="css-1gf6lcl"><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span></div></span></span></li><li><div class="minor">Compensation and Benefits</div><span class="subRatings__SubRatingsStyles__gdBars gdBars gdRatings med" title="5.0"><span class="gdStars gdRatings common__StarStyles__gdStars"><span class="rating"><span title="5.0"></span></span><div font-size="sm" class="css-1gf6lcl"><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span></div></span></span></li><li><div class="minor">Senior Management</div><span class="subRatings__SubRatingsStyles__gdBars gdBars gdRatings med" title="5.0"><span class="gdStars gdRatings common__StarStyles__gdStars"><span class="rating"><span title="5.0"></span></span><div font-size="sm" class="css-1gf6lcl"><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span><span role="button">★</span></div></span></span></li></ul></div></span></div><div class="d-lg-inline-block"><div class="author minor"><span class="authorInfo"><span class="authorJobTitle middle">Current Employee - Software Developer</span>\xa0</span></div></div><div><div class="row reviewBodyCell recommends"><div class="col-sm-4"><i class="sqLed middle sm mr-xsm green"></i><span>Recommends</span></div><div class="col-sm-4"><i class="sqLed middle sm mr-xsm green"></i><span>Positive Outlook</span></div><div class="col-sm-4"><i class="sqLed middle sm mr-xsm green"></i><span>Approves of CEO</span></div></div></div><p class="mainText mb-0">I have been working at Banana Republic part-time for more than a year</p><div class="v2__EIReviewDetailsV2__fullWidth "><p class="strong mb-0 mt-xsm">Pros</p><p class="mt-0 mb-xsm v2__EIReviewDetailsV2__bodyColor v2__EIReviewDetailsV2__lineHeightLarge v2__EIReviewDetailsV2__isExpanded "><span data-test="pros">Great management, good engineering values and nice office working space.</span></p></div><div class="v2__EIReviewDetailsV2__fullWidth "><p class="strong mb-0 mt-xsm">Cons</p><p class="mt-0 mb-xsm v2__EIReviewDetailsV2__bodyColor v2__EIReviewDetailsV2__lineHeightLarge v2__EIReviewDetailsV2__isExpanded "><span data-test="cons">It can get very fast-paced.</span></p></div><div class="row mt-xsm mx-0"></div><div class="row justify-content-around justify-content-md-between mt-lg"><div class="shareContent d-flex justify-content-center"><div class="share-callout-inline"><div class="callout-container"><ul class="d-table social-share-icon-list p-0"><li class="cell"><a class="social-share-icon facebook-share" href="#shareOnFacebook" data-url="http://www.glassdoor.co.uk/Reviews/Employee-Review-Banana-Republic-RVW31820120.htm" data-label="facebook"><span class="offScreen">Share on Facebook</span></a></li><li class="cell"><a class="social-share-icon twitter-share" href="https://twitter.com/share?url=http://www.glassdoor.co.uk/Reviews/Employee-Review-Banana-Republic-RVW31820120.htm&amp;amp;text=Banana%20Republic+review+on+%23Glassdoor%3A+%22Best%20place%20I\'ve%20worked%22" data-label="twitter"><span class="offScreen">Share on Twitter</span></a></li><li class="cell whatsapp"><a class="social-share-icon whatsapp-share" href="whatsapp://send?text=http://www.glassdoor.co.uk/Reviews/Employee-Review-Banana-Republic-RVW31820120.htm" data-action="share/whatsapp/share" data-label="whatsapp"><span class="offScreen">Share on WhatsApp</span></a></li><li class="cell"><a class="social-share-icon email-share" href="mailto:?Subject=Banana%20Republic%20review%20on%20Glassdoor&amp;body=Read%20this%20review%20of%20Banana%20Republic%20on%20Glassdoor.%20%22Best%20place%20I\'ve%20worked%22%C2%A0http://www.glassdoor.co.uk/Reviews/Employee-Review-Banana-Republic-RVW31820120.htm" data-label="email"><span class="offScreen">Share via Email</span></a></li><li class="cell"><a class="social-share-icon link-share" href="http://www.glassdoor.co.uk/Reviews/Employee-Review-Banana-Republic-RVW31820120.htm" data-label="link"><span class="offScreen">Copy Link</span></a></li><li class="cell linkCopySuccess"><span class="social-share-icon icon-check showDesk"></span><span>Link Copied!</span></li></ul></div></div></div><div class="d-flex"><div class="mr-md"><style data-emotion-css="glrvaa">.css-glrvaa{border:1px solid transparent;border-radius:3px;border-color:transparent;font-weight:bold;font-size:15px;color:#fff;cursor:pointer;padding:8px 16px;display:inline-block;line-height:1.6;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;font-family:\'Lato\';white-space:nowrap;overflow:hidden;text-overflow:ellipsis;min-width:88px;}.css-glrvaa,button.css-glrvaa{color:#1861bf;background-color:#fff;border-color:#1861bf;padding:3px 16px;}.css-glrvaa:focus,button.css-glrvaa:focus{outline:0;}.css-glrvaa:link,button.css-glrvaa:link,.css-glrvaa:visited,button.css-glrvaa:visited{color:#1861bf;}@media not all and (pointer:coarse){.css-glrvaa:hover,button.css-glrvaa:hover{background-color:#1861bf;color:#fff;}.css-glrvaa:hover svg,button.css-glrvaa:hover svg{color:currentColor;}}.css-glrvaa[disabled],button.css-glrvaa[disabled]{color:#abccf7;background-color:#fff;border-color:#abccf7;cursor:not-allowed;}</style><button class="gd-ui-button  css-glrvaa">Helpful<!-- --> </button></div><div><span class="flagContent" data-disp-type="review" data-id="31820120" data-member="false" data-review-link="/Reviews/Employee-Review-Banana-Republic-RVW31820120.htm" data-type="EMPLOYER_REVIEW"><button class="px-0 mx-0 simple gd-btn gd-btn-2 gd-btn-sm gd-btn-icon gradient" title="Flag as Inappropriate" type="button"><i class="icon-flag-content"><span>Flag as Inappropriate</span></i><i class="hlpr"></i><span class="offScreen">Flag as Inappropriate</span></button><span class="posPt"></span></span></div></div></div></div></div></div>'''

# %%
soup = BeautifulSoup(html, features="lxml")

# %%
soup
# Out:
# <html><body><div class="gdReview"><div class="d-flex justify-content-between"><div class="d-flex align-items-center"><time class="date subtle small" datetime="Wed Feb 12 2020 01:30:00 GMT-0800 (Pacific Standard Time)">12 February 2020</time></div></div><div class="row mt"><div class="col-sm-1"><span class="sqLogo smSqLogo logoOverlay"><img alt="Banana Republic Logo" class="lazy lazy-loaded" data-original="https://media.glassdoor.com/sql/23057/banana-republic-squarelogo-1580180139279.png" data-original-2x="https://media.glassdoor.com/sqll/23057/banana-republic-squarelogo-1580180139279.png" data-retina-ok="true" src="https://media.glassdoor.com/sql/23057/banana-republic-squarelogo-1580180139279.png" style="opacity:1" title=""/></span></div><div class="col-sm-11 pl-sm-lg mx-0"><h2 class="h2 summary strong mt-0 mb-xsm"><a class="reviewLink" href="/Reviews/Employee-Review-Banana-Republic-RVW31820120.htm">"Best place I've worked"</a></h2><div class="mr-xsm d-lg-inline-block"><span class="g
# ...

# %%
for rev in response.css("div.gdReview"):
pro_con_head = "p.strong.mb-0.mt-xsm::text"
pro_con_text = "p.mt-0.mb-xsm.v2__EIReviewDetailsV2__bodyColor.v2__EIReviewDetailsV2__lineHeightLarge span::text"
{proscons.css(pro_con_head).get():    proscons.css(pro_con_text).get() for proscons in rev.css("div.v2__EIReviewDetailsV2__fullWidth")}


class="v2__EIReviewDetailsV2__continueReading v2__EIReviewDetailsV2__clickable"
